# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df = pd.concat(map(pd.read_csv, ["/content/college_1.csv", "/content/college_2.csv"]), ignore_index=True)
print(df)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
filt = (df['CodeKata Score'] > 15000)
df[filt]
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
df[filt].to_csv('Exceeded_expectations.csv')
df= pd.read_csv('Exceeded_expectations.csv')
df
# Out:
#    Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0           0      A.Dharani    82.0   20.0              24500
# 1           1    V.JEEVITHA     82.0   20.0              21740
# 2           2    HEMAVATHI.R   100.0  100.0              19680
# 3          84  ASHOK KUMAR K   100.0   31.0              19400
#
#    CodeKata Score                              Department  Rising  python_en  \
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 3           19400  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
filt2 = (df['CodeKata Score'] > 10000) &(df['CodeKata Score'] < 15000)
df[filt2]
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
df[filt2].to_csv('Reached_expectations.csv')
df= pd.read_csv('Reached_expectations.csv')
df
# Out:
#    Unnamed: 0               Name  python  mysql  Previous Geekions  \
# 0           3        Mugunthan S   100.0   47.0              10610
# 1          85            Chandru     0.0    0.0              14150
# 2          86  Ganesh Ramkumar R    -1.0   24.0               8790
# 3          87    Bodipudi Harini    -1.0   35.0              10040
#
#    CodeKata Score                                 Department  Rising  \
# 0           10610           Computer Science and Engineering       0
# 1           14490           Computer Science and Engineering     340
# 2           10790           Computer Science and Engineering    2000
# 3           10040  Electronics and Communication Engineering       0
#
#    python_en  computational_thinking
# 0        NaN                     NaN
# 1       20.0                     0.0
# 2       55.0                     6.0
# 3        0.0                    -1.0

# %%
filt3 = (df['CodeKata Score'] > 7000) &(df['CodeKata Score'] < 10000)
df[filt3]
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %%
df[filt3].to_csv('Needs_Improvement.csv')
df= pd.read_csv('Needs_Improvement.csv')
df
# Out:
#     Unnamed: 0                    Name  python  mysql  Previous Geekions  \
# 0            4             Sathammai.S   100.0    8.0               8980
# 1            5            NIVEESHWAR S   100.0    0.0               8200
# 2            6           KALAIARASAN K    85.0   47.0               7750
# 3            7    MOHAMED ZUBAIR AHMED    82.0    4.0               7020
# 4           88               VIINU V P    -1.0   24.0               9150
# 5           89              Poojitha Y     0.0   35.0               7210
# 6           90  Gowtham Chandrasekaran    -1.0    0.0               7250
# 7           91               Gowtham R    -1.0    4.0               8650
# 8           92                shifak N    58.0    0.0               5180
# 9           93                 Balaji     -1.0   20.0               6170
# 10          94                Rushitha    -1.0   62.0               7470
# 11          95    Balaraman Muthupandi    -1.0    0.0               7670
# ...

# %%
filt4 = (df['CodeKata Score'] < 7000)
df[filt4]
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %%
df[filt4].to_csv('Unsatisfactory.csv', index=False)

# %%
df= pd.read_csv('Unsatisfactory.csv')
df
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['Previous Geekions'].mean() #Average of previous week geekions
# Out:
# 2112.043010752688

# %% [markdown]
# ###### No of students participated

# %%
df['CodeKata Score'].mean() # this week geekions
# Out:
# 2193.2258064516127

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['python'].value_counts(normalize=True)  #Average completion of python course
# Out:
#  100.0    0.344538
# -1.0      0.226891
#  82.0     0.092437
#  0.0      0.075630
#  85.0     0.033613
#  16.0     0.033613
#  29.0     0.016807
#  56.0     0.016807
#  32.0     0.016807
#  3.0      0.016807
#  61.0     0.008403
#  58.0     0.008403
#  45.0     0.008403
#  95.0     0.008403
#  30.0     0.008403
#  97.5     0.008403
#  93.0     0.008403
#  11.0     0.008403
#  43.0     0.008403
#  53.0     0.008403
#  74.0     0.008403
#  87.5     0.008403
#  50.0     0.008403
#  27.0     0.008403
#  24.0     0.008403
# Name: python, dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(3, 'Rising')
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(3, 'CodeKata Score')
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
filt = (df['Department'] == 'Computer Science and Engineering')
df[filt]
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0            A.Dharani    82.0   20.0              24500           24500
# 1          V.JEEVITHA     82.0   20.0              21740           21740
# 2          HEMAVATHI.R   100.0  100.0              19680           19680
# 3          Mugunthan S   100.0   47.0              10610           10610
# 4          Sathammai.S   100.0    8.0               8980            8980
# ..                 ...     ...    ...                ...             ...
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 112      M.Karthikeyan    -1.0    4.0               4020            4020
# 114      praveen raj j    24.0    0.0               2380            2380
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                            Department  Rising  python_en  \
# ...

# %%
CSE = df[filt]
CSE['CodeKata Score'].sum()
# Out:
# 320025

# %%
filt2 = (df['Department'] == 'Electronics and Electrical Engineering')
df[filt2]
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 64       k.parvathi   100.0  100.0                260             260
# 71      m.keerthana    97.5    0.0                120             120
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
# 77       J.JAYANTHI   100.0  100.0                 40              40
# 78     vikneshwaran   100.0    4.0                 40              40
# 79     KarthikeyanS    45.0    0.0                  0               0
# 80         BARATH.P    29.0    0.0                  0               0
# 81    N.Ajith kumar    82.0    0.0                  0               0
# 82     mohamed nabi     0.0    0.0                  0               0
# 83   yaser ahamed.A     0.0   27.0                  0               0
# ...

# %%
EEE = df[filt2]
EEE['CodeKata Score'].sum()
# Out:
# 53800

# %%
filt3 = (df['Department'] == 'Electronics and Communication Engineering')
df[filt3]
# Out:
#                            Name  python   mysql  Previous Geekions  \
# 6                 KALAIARASAN K    85.0   47.00               7750
# 8                    J.SUGANTHI    27.0   50.00               5860
# 10              Iyappan Samiraj    50.0   24.00               5400
# 14              Melvin Dukles.R    56.0   20.00               4800
# 17                  v.vithyasri   100.0   12.00               4370
# 18           Abirami Anbazhagan   100.0    0.00               4320
# 21                 kamalishwari    32.0   20.00               3665
# 25                    Tpavithra   100.0   24.00               3200
# 27                     shankari    87.5   20.00               3000
# 32                   SarumathiR    16.0   35.00               2240
# 35                     Barath D    74.0    4.00               1910
# 39                      vignesh    85.0    0.00               1740
# 42                    ABIRAMI.S    82.0    0.00               1580
# ...

# %%
ECE = df[filt3]
ECE['CodeKata Score'].sum()
# Out:
# 108335

# %%
df['Department'].value_counts(normalize=True)
# Out:
# Computer Science and Engineering             0.529412
# Electronics and Communication Engineering    0.327731
# Electronics and Electrical Engineering       0.142857
# Name: Department, dtype: float64

# %%
from matplotlib import pyplot as plt 

# Data to plot
labels = 'CS','ECE','EEE'
sizes = [320025, 108335, 53800]
colors = ['gold', 'yellowgreen', 'lightcoral']
neth=plt.axes()
neth.legend(title="dptmt",loc="center")
neth.set_title("dptmt wise CK")
# Plot
plt.pie(sizes, labels=labels, colors=colors,shadow=True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
cse.sort_values(by=['python', 'mysql', 'CodeKata Score', 'python_en', 'computational_thinking'], ascending=[False,False,False,False,False]).loc['Computer Science and Engineering	']
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 2          HEMAVATHI.R   100.0  100.0              19680           19680
# 15            Pavithra   100.0  100.0               4600            4600
# 22             Yuvasri   100.0  100.0               3460            3460
# 24             MEERA.M   100.0  100.0               3200            3200
# 26       sri dharshini   100.0  100.0               3110            3110
# ..                 ...     ...    ...                ...             ...
# 109       SHAIK DANISH    -1.0    0.0               4050            4820
# 110          sridhar.s    -1.0    0.0               3860            4440
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                            Department  Rising  python_en  \
# ...

# %%
df.sort_values(by=['python', 'mysql', 'CodeKata Score', 'python_en', 'computational_thinking'], ascending=[False,False,False,False,False])
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 2          HEMAVATHI.R   100.0  100.0              19680           19680
# 15            Pavithra   100.0  100.0               4600            4600
# 22             Yuvasri   100.0  100.0               3460            3460
# 24             MEERA.M   100.0  100.0               3200            3200
# 26       sri dharshini   100.0  100.0               3110            3110
# ..                 ...     ...    ...                ...             ...
# 109       SHAIK DANISH    -1.0    0.0               4050            4820
# 110          sridhar.s    -1.0    0.0               3860            4440
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                            Department  Rising  python_en  \
# ...

# %%
import matplotlib.pyplot as plt
 
x=['hemavathi/nCSE', 'k.parvathi/nEEE', 't.pavithra/nECE']
 
# giving the values against
# each value at x axis
y=[5, 24, 35, 67, 12]
plt.bar(x, y)
 
# setting x-label as pen sold
plt.xlabel("pen sold")
 
# setting y_label as price
plt.ylabel("price")  
plt.title(" Vertical bar graph")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
   
data = {'python': [100,100,100],
        'msql': [100,100,24],
        'codekata':[196,3,32]
       }
df = pd.DataFrame(data,columns=['python','msql','codekata'], index = ['hemavathi(CSE)', 'k.parvathi(EEE)', 't.pavithra(ECE)'])

df.plot.barh()

plt.title('dprtmt wise toppers')
plt.ylabel('Product')
plt.xlabel('Quantity')
plt.show()
